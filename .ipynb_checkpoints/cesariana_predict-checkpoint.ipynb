# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Read-DataSet" data-toc-modified-id="Read-DataSet-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Read DataSet</a></span></li><li><span><a href="#Analise-Exploratória" data-toc-modified-id="Analise-Exploratória-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Analise Exploratória</a></span></li></ul></div>

# %% [markdown]
# # Importando Lybrarys

# %%
import pandas as pd
import numpy as  np

#bibliotecas Gráficas
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read DataSet

# %%
df_cesaria = pd.read_excel ('cesarianadataset.xlsx')

# %%
df_cesaria.head()
# Out:
#    idade  nr_parto  tempo_parto  pressao_sangue  prblm_coracao  Cesariana
# 0     22         1            0               2              0          0
# 1     26         2            0               1              0          1
# 2     26         2            1               1              0          0
# 3     28         1            0               2              0          0
# 4     22         2            0               1              0          1

# %% [markdown]
# ## Analise Exploratória

# %%
df_cesaria.idade.hist()
plt.suptitle('Distribuição da Idade')
# Out:
# Text(0.5, 0.98, 'Distribuição da Idade')

# %%
df_cesaria.loc[df_cesaria.idade  <  12,'Faixa_idade'] = 'Crianca'
df_cesaria.loc[(df_cesaria.idade >= 12) & (df_cesaria.idade < 22),'Faixa_idade']  = 'Jovem'
df_cesaria.loc[(df_cesaria.idade >= 22) & (df_cesaria.idade < 31),'Faixa_idade']  = 'Adulto'
df_cesaria.loc[(df_cesaria.idade >= 31) & (df_cesaria.idade < 41),'Faixa_idade']  = 'Experiente'
df_cesaria.loc[df_cesaria.idade  >= 41 ,'Faixa_idade'] = 'Senior'

# %%
df_cesaria
# Out:
#     idade  nr_parto  tempo_parto  pressao_sangue  prblm_coracao  Cesariana  \
# 0      22         1            0               2              0          0
# 1      26         2            0               1              0          1
# 2      26         2            1               1              0          0
# 3      28         1            0               2              0          0
# 4      22         2            0               1              0          1
# 5      26         1            1               0              0          0
# 6      27         2            0               1              0          0
# 7      32         3            0               1              0          1
# 8      28         2            0               1              0          0
# 9      27         1            1               1              0          1
# 10     36         1            0               1              0          0
# 11     33         1            1               0              0          1
# 12     23         1            1               1              0          0
# 13     20         1            0               1              1          0
# 14     29         1            2               0              1          1
# 15     25         1            2               0              0          0
# 16     25         1            0               1              0          0
# 17     20         1            2               2              0          1
# 18     37         3            0               1              1          1
# 19     24         1            2               0              1          1
# 20     26         1            1               1              0          0
# 21     33         2            0               0              1          1
# 22     25         1            1               2              0          0
# 23     27         1            0               0              1          1
# 24     20         1            0               2              1          1
# 25     18         1            0               1              0          0
# 26     18         1            1               2              1          1
# 27     30         1            0               1              0          0
# 28     32         1            0               2              1          1
# 29     26         2            1               1              1          0
# ..    ...       ...          ...             ...            ...        ...
# 50     33         3            2               1              1          0
# 51     21         2            1               0              1          1
# 52     30         3            2               2              0          0
# 53     35         1            1               0              0          0
# 54     29         2            0               1              1          1
# 55     25         2            0               1              0          0
# 56     32         3            1               0              1          1
# 57     21         1            0               0              0          1
# 58     26         1            0               2              0          1
# 59     30         2            1               2              1          1
# 60     22         1            2               2              0          0
# 61     19         1            0               1              0          1
# 62     32         2            0               0              0          1
# 63     32         2            0               1              1          1
# 64     31         1            2               2              1          0
# 65     35         2            0               1              0          1
# 66     28         3            0               1              0          1
# 67     29         2            0               1              1          0
# 68     25         1            0               0              0          1
# 69     27         2            2               0              0          0
# 70     17         1            0               0              0          1
# 71     29         1            2               0              1          1
# 72     28         2            0               1              0          0
# 73     32         3            0               1              1          0
# 74     38         3            2               2              1          1
# 75     27         2            1               1              0          0
# 76     33         4            0               1              0          1
# 77     29         2            1               2              0          1
# 78     25         1            2               0              0          1
# 79     24         2            2               1              0          0
#
#    Faixa_idade
# 0       Adulto
# 1       Adulto
# 2       Adulto
# 3       Adulto
# 4       Adulto
# 5       Adulto
# 6       Adulto
# 7   Experiente
# 8       Adulto
# 9       Adulto
# 10  Experiente
# 11  Experiente
# 12      Adulto
# 13       Jovem
# 14      Adulto
# 15      Adulto
# 16      Adulto
# 17       Jovem
# 18  Experiente
# 19      Adulto
# 20      Adulto
# 21  Experiente
# 22      Adulto
# 23      Adulto
# 24       Jovem
# 25       Jovem
# 26       Jovem
# 27      Adulto
# 28  Experiente
# 29      Adulto
# ..         ...
# 50  Experiente
# 51       Jovem
# 52      Adulto
# 53  Experiente
# 54      Adulto
# 55      Adulto
# 56  Experiente
# 57       Jovem
# 58      Adulto
# 59      Adulto
# 60      Adulto
# 61       Jovem
# 62  Experiente
# 63  Experiente
# 64  Experiente
# 65  Experiente
# 66      Adulto
# 67      Adulto
# 68      Adulto
# 69      Adulto
# 70       Jovem
# 71      Adulto
# 72      Adulto
# 73  Experiente
# 74  Experiente
# 75      Adulto
# 76  Experiente
# 77      Adulto
# 78      Adulto
# 79      Adulto
#
# [80 rows x 7 columns]

# %%
df_cesaria.loc[df_cesaria.tempo_parto  ==  0,'tempo_parto_desc'] = 'Pontual'
df_cesaria.loc[df_cesaria.tempo_parto  ==  1,'tempo_parto_desc'] = 'Prematuro'
df_cesaria.loc[df_cesaria.tempo_parto  ==  2,'tempo_parto_desc'] = 'Tardio'

# %%
df_cesaria
# Out:
#     idade  nr_parto  tempo_parto  pressao_sangue  prblm_coracao  Cesariana  \
# 0      22         1            0               2              0          0
# 1      26         2            0               1              0          1
# 2      26         2            1               1              0          0
# 3      28         1            0               2              0          0
# 4      22         2            0               1              0          1
# 5      26         1            1               0              0          0
# 6      27         2            0               1              0          0
# 7      32         3            0               1              0          1
# 8      28         2            0               1              0          0
# 9      27         1            1               1              0          1
# 10     36         1            0               1              0          0
# 11     33         1            1               0              0          1
# 12     23         1            1               1              0          0
# 13     20         1            0               1              1          0
# 14     29         1            2               0              1          1
# 15     25         1            2               0              0          0
# 16     25         1            0               1              0          0
# 17     20         1            2               2              0          1
# 18     37         3            0               1              1          1
# 19     24         1            2               0              1          1
# 20     26         1            1               1              0          0
# 21     33         2            0               0              1          1
# 22     25         1            1               2              0          0
# 23     27         1            0               0              1          1
# 24     20         1            0               2              1          1
# 25     18         1            0               1              0          0
# 26     18         1            1               2              1          1
# 27     30         1            0               1              0          0
# 28     32         1            0               2              1          1
# 29     26         2            1               1              1          0
# ..    ...       ...          ...             ...            ...        ...
# 50     33         3            2               1              1          0
# 51     21         2            1               0              1          1
# 52     30         3            2               2              0          0
# 53     35         1            1               0              0          0
# 54     29         2            0               1              1          1
# 55     25         2            0               1              0          0
# 56     32         3            1               0              1          1
# 57     21         1            0               0              0          1
# 58     26         1            0               2              0          1
# 59     30         2            1               2              1          1
# 60     22         1            2               2              0          0
# 61     19         1            0               1              0          1
# 62     32         2            0               0              0          1
# 63     32         2            0               1              1          1
# 64     31         1            2               2              1          0
# 65     35         2            0               1              0          1
# 66     28         3            0               1              0          1
# 67     29         2            0               1              1          0
# 68     25         1            0               0              0          1
# 69     27         2            2               0              0          0
# 70     17         1            0               0              0          1
# 71     29         1            2               0              1          1
# 72     28         2            0               1              0          0
# 73     32         3            0               1              1          0
# 74     38         3            2               2              1          1
# 75     27         2            1               1              0          0
# 76     33         4            0               1              0          1
# 77     29         2            1               2              0          1
# 78     25         1            2               0              0          1
# 79     24         2            2               1              0          0
#
#    Faixa_idade tempo_parto_desc
# 0       Adulto          Pontual
# 1       Adulto          Pontual
# 2       Adulto        Prematuro
# 3       Adulto          Pontual
# 4       Adulto          Pontual
# 5       Adulto        Prematuro
# 6       Adulto          Pontual
# 7   Experiente          Pontual
# 8       Adulto          Pontual
# 9       Adulto        Prematuro
# 10  Experiente          Pontual
# 11  Experiente        Prematuro
# 12      Adulto        Prematuro
# 13       Jovem          Pontual
# 14      Adulto           Tardio
# 15      Adulto           Tardio
# 16      Adulto          Pontual
# 17       Jovem           Tardio
# 18  Experiente          Pontual
# 19      Adulto           Tardio
# 20      Adulto        Prematuro
# 21  Experiente          Pontual
# 22      Adulto        Prematuro
# 23      Adulto          Pontual
# 24       Jovem          Pontual
# 25       Jovem          Pontual
# 26       Jovem        Prematuro
# 27      Adulto          Pontual
# 28  Experiente          Pontual
# 29      Adulto        Prematuro
# ..         ...              ...
# 50  Experiente           Tardio
# 51       Jovem        Prematuro
# 52      Adulto           Tardio
# 53  Experiente        Prematuro
# 54      Adulto          Pontual
# 55      Adulto          Pontual
# 56  Experiente        Prematuro
# 57       Jovem          Pontual
# 58      Adulto          Pontual
# 59      Adulto        Prematuro
# 60      Adulto           Tardio
# 61       Jovem          Pontual
# 62  Experiente          Pontual
# 63  Experiente          Pontual
# 64  Experiente           Tardio
# 65  Experiente          Pontual
# 66      Adulto          Pontual
# 67      Adulto          Pontual
# 68      Adulto          Pontual
# 69      Adulto           Tardio
# 70       Jovem          Pontual
# 71      Adulto           Tardio
# 72      Adulto          Pontual
# 73  Experiente          Pontual
# 74  Experiente           Tardio
# 75      Adulto        Prematuro
# 76  Experiente          Pontual
# 77      Adulto        Prematuro
# 78      Adulto           Tardio
# 79      Adulto           Tardio
#
# [80 rows x 8 columns]

# %%
df_cesaria.loc[df_cesaria.pressao_sangue  ==  0,'pressao_sangue_desc'] = 'Baixo'
df_cesaria.loc[df_cesaria.pressao_sangue  ==  1,'pressao_sangue_desc'] = 'Normal'
df_cesaria.loc[df_cesaria.pressao_sangue  ==  2,'pressao_sangue_desc'] = 'Alto'

# %%
df_cesaria
# Out:
#     idade  nr_parto  tempo_parto  pressao_sangue  prblm_coracao  Cesariana  \
# 0      22         1            0               2              0          0
# 1      26         2            0               1              0          1
# 2      26         2            1               1              0          0
# 3      28         1            0               2              0          0
# 4      22         2            0               1              0          1
# 5      26         1            1               0              0          0
# 6      27         2            0               1              0          0
# 7      32         3            0               1              0          1
# 8      28         2            0               1              0          0
# 9      27         1            1               1              0          1
# 10     36         1            0               1              0          0
# 11     33         1            1               0              0          1
# 12     23         1            1               1              0          0
# 13     20         1            0               1              1          0
# 14     29         1            2               0              1          1
# 15     25         1            2               0              0          0
# 16     25         1            0               1              0          0
# 17     20         1            2               2              0          1
# 18     37         3            0               1              1          1
# 19     24         1            2               0              1          1
# 20     26         1            1               1              0          0
# 21     33         2            0               0              1          1
# 22     25         1            1               2              0          0
# 23     27         1            0               0              1          1
# 24     20         1            0               2              1          1
# 25     18         1            0               1              0          0
# 26     18         1            1               2              1          1
# 27     30         1            0               1              0          0
# 28     32         1            0               2              1          1
# 29     26         2            1               1              1          0
# ..    ...       ...          ...             ...            ...        ...
# 50     33         3            2               1              1          0
# 51     21         2            1               0              1          1
# 52     30         3            2               2              0          0
# 53     35         1            1               0              0          0
# 54     29         2            0               1              1          1
# 55     25         2            0               1              0          0
# 56     32         3            1               0              1          1
# 57     21         1            0               0              0          1
# 58     26         1            0               2              0          1
# 59     30         2            1               2              1          1
# 60     22         1            2               2              0          0
# 61     19         1            0               1              0          1
# 62     32         2            0               0              0          1
# 63     32         2            0               1              1          1
# 64     31         1            2               2              1          0
# 65     35         2            0               1              0          1
# 66     28         3            0               1              0          1
# 67     29         2            0               1              1          0
# 68     25         1            0               0              0          1
# 69     27         2            2               0              0          0
# 70     17         1            0               0              0          1
# 71     29         1            2               0              1          1
# 72     28         2            0               1              0          0
# 73     32         3            0               1              1          0
# 74     38         3            2               2              1          1
# 75     27         2            1               1              0          0
# 76     33         4            0               1              0          1
# 77     29         2            1               2              0          1
# 78     25         1            2               0              0          1
# 79     24         2            2               1              0          0
#
#    Faixa_idade tempo_parto_desc pressao_sangue_desc
# 0       Adulto          Pontual                Alto
# 1       Adulto          Pontual              Normal
# 2       Adulto        Prematuro              Normal
# 3       Adulto          Pontual                Alto
# 4       Adulto          Pontual              Normal
# 5       Adulto        Prematuro               Baixo
# 6       Adulto          Pontual              Normal
# 7   Experiente          Pontual              Normal
# 8       Adulto          Pontual              Normal
# 9       Adulto        Prematuro              Normal
# 10  Experiente          Pontual              Normal
# 11  Experiente        Prematuro               Baixo
# 12      Adulto        Prematuro              Normal
# 13       Jovem          Pontual              Normal
# 14      Adulto           Tardio               Baixo
# 15      Adulto           Tardio               Baixo
# 16      Adulto          Pontual              Normal
# 17       Jovem           Tardio                Alto
# 18  Experiente          Pontual              Normal
# 19      Adulto           Tardio               Baixo
# 20      Adulto        Prematuro              Normal
# 21  Experiente          Pontual               Baixo
# 22      Adulto        Prematuro                Alto
# 23      Adulto          Pontual               Baixo
# 24       Jovem          Pontual                Alto
# 25       Jovem          Pontual              Normal
# 26       Jovem        Prematuro                Alto
# 27      Adulto          Pontual              Normal
# 28  Experiente          Pontual                Alto
# 29      Adulto        Prematuro              Normal
# ..         ...              ...                 ...
# 50  Experiente           Tardio              Normal
# 51       Jovem        Prematuro               Baixo
# 52      Adulto           Tardio                Alto
# 53  Experiente        Prematuro               Baixo
# 54      Adulto          Pontual              Normal
# 55      Adulto          Pontual              Normal
# 56  Experiente        Prematuro               Baixo
# 57       Jovem          Pontual               Baixo
# 58      Adulto          Pontual                Alto
# 59      Adulto        Prematuro                Alto
# 60      Adulto           Tardio                Alto
# 61       Jovem          Pontual              Normal
# 62  Experiente          Pontual               Baixo
# 63  Experiente          Pontual              Normal
# 64  Experiente           Tardio                Alto
# 65  Experiente          Pontual              Normal
# 66      Adulto          Pontual              Normal
# 67      Adulto          Pontual              Normal
# 68      Adulto          Pontual               Baixo
# 69      Adulto           Tardio               Baixo
# 70       Jovem          Pontual               Baixo
# 71      Adulto           Tardio               Baixo
# 72      Adulto          Pontual              Normal
# 73  Experiente          Pontual              Normal
# 74  Experiente           Tardio                Alto
# 75      Adulto        Prematuro              Normal
# 76  Experiente          Pontual              Normal
# 77      Adulto        Prematuro                Alto
# 78      Adulto           Tardio               Baixo
# 79      Adulto           Tardio              Normal
#
# [80 rows x 9 columns]

# %%
df_cesaria.loc[df_cesaria.prblm_coracao  ==  0,'problema_coracao_desc'] = 'Apto'
df_cesaria.loc[df_cesaria.prblm_coracao  ==  1,'problema_coracao_desc'] = 'Inepto'

# %%
df_cesaria
# Out:
#     idade  nr_parto  tempo_parto  pressao_sangue  prblm_coracao  Cesariana  \
# 0      22         1            0               2              0          0
# 1      26         2            0               1              0          1
# 2      26         2            1               1              0          0
# 3      28         1            0               2              0          0
# 4      22         2            0               1              0          1
# 5      26         1            1               0              0          0
# 6      27         2            0               1              0          0
# 7      32         3            0               1              0          1
# 8      28         2            0               1              0          0
# 9      27         1            1               1              0          1
# 10     36         1            0               1              0          0
# 11     33         1            1               0              0          1
# 12     23         1            1               1              0          0
# 13     20         1            0               1              1          0
# 14     29         1            2               0              1          1
# 15     25         1            2               0              0          0
# 16     25         1            0               1              0          0
# 17     20         1            2               2              0          1
# 18     37         3            0               1              1          1
# 19     24         1            2               0              1          1
# 20     26         1            1               1              0          0
# 21     33         2            0               0              1          1
# 22     25         1            1               2              0          0
# 23     27         1            0               0              1          1
# 24     20         1            0               2              1          1
# 25     18         1            0               1              0          0
# 26     18         1            1               2              1          1
# 27     30         1            0               1              0          0
# 28     32         1            0               2              1          1
# 29     26         2            1               1              1          0
# ..    ...       ...          ...             ...            ...        ...
# 50     33         3            2               1              1          0
# 51     21         2            1               0              1          1
# 52     30         3            2               2              0          0
# 53     35         1            1               0              0          0
# 54     29         2            0               1              1          1
# 55     25         2            0               1              0          0
# 56     32         3            1               0              1          1
# 57     21         1            0               0              0          1
# 58     26         1            0               2              0          1
# 59     30         2            1               2              1          1
# 60     22         1            2               2              0          0
# 61     19         1            0               1              0          1
# 62     32         2            0               0              0          1
# 63     32         2            0               1              1          1
# 64     31         1            2               2              1          0
# 65     35         2            0               1              0          1
# 66     28         3            0               1              0          1
# 67     29         2            0               1              1          0
# 68     25         1            0               0              0          1
# 69     27         2            2               0              0          0
# 70     17         1            0               0              0          1
# 71     29         1            2               0              1          1
# 72     28         2            0               1              0          0
# 73     32         3            0               1              1          0
# 74     38         3            2               2              1          1
# 75     27         2            1               1              0          0
# 76     33         4            0               1              0          1
# 77     29         2            1               2              0          1
# 78     25         1            2               0              0          1
# 79     24         2            2               1              0          0
#
#    Faixa_idade tempo_parto_desc pressao_sangue_desc problema_coracao_desc
# 0       Adulto          Pontual                Alto                  Apto
# 1       Adulto          Pontual              Normal                  Apto
# 2       Adulto        Prematuro              Normal                  Apto
# 3       Adulto          Pontual                Alto                  Apto
# 4       Adulto          Pontual              Normal                  Apto
# 5       Adulto        Prematuro               Baixo                  Apto
# 6       Adulto          Pontual              Normal                  Apto
# 7   Experiente          Pontual              Normal                  Apto
# 8       Adulto          Pontual              Normal                  Apto
# 9       Adulto        Prematuro              Normal                  Apto
# 10  Experiente          Pontual              Normal                  Apto
# 11  Experiente        Prematuro               Baixo                  Apto
# 12      Adulto        Prematuro              Normal                  Apto
# 13       Jovem          Pontual              Normal                Inepto
# 14      Adulto           Tardio               Baixo                Inepto
# 15      Adulto           Tardio               Baixo                  Apto
# 16      Adulto          Pontual              Normal                  Apto
# 17       Jovem           Tardio                Alto                  Apto
# 18  Experiente          Pontual              Normal                Inepto
# 19      Adulto           Tardio               Baixo                Inepto
# 20      Adulto        Prematuro              Normal                  Apto
# 21  Experiente          Pontual               Baixo                Inepto
# 22      Adulto        Prematuro                Alto                  Apto
# 23      Adulto          Pontual               Baixo                Inepto
# 24       Jovem          Pontual                Alto                Inepto
# 25       Jovem          Pontual              Normal                  Apto
# 26       Jovem        Prematuro                Alto                Inepto
# 27      Adulto          Pontual              Normal                  Apto
# 28  Experiente          Pontual                Alto                Inepto
# 29      Adulto        Prematuro              Normal                Inepto
# ..         ...              ...                 ...                   ...
# 50  Experiente           Tardio              Normal                Inepto
# 51       Jovem        Prematuro               Baixo                Inepto
# 52      Adulto           Tardio                Alto                  Apto
# 53  Experiente        Prematuro               Baixo                  Apto
# 54      Adulto          Pontual              Normal                Inepto
# 55      Adulto          Pontual              Normal                  Apto
# 56  Experiente        Prematuro               Baixo                Inepto
# 57       Jovem          Pontual               Baixo                  Apto
# 58      Adulto          Pontual                Alto                  Apto
# 59      Adulto        Prematuro                Alto                Inepto
# 60      Adulto           Tardio                Alto                  Apto
# 61       Jovem          Pontual              Normal                  Apto
# 62  Experiente          Pontual               Baixo                  Apto
# 63  Experiente          Pontual              Normal                Inepto
# 64  Experiente           Tardio                Alto                Inepto
# 65  Experiente          Pontual              Normal                  Apto
# 66      Adulto          Pontual              Normal                  Apto
# 67      Adulto          Pontual              Normal                Inepto
# 68      Adulto          Pontual               Baixo                  Apto
# 69      Adulto           Tardio               Baixo                  Apto
# 70       Jovem          Pontual               Baixo                  Apto
# 71      Adulto           Tardio               Baixo                Inepto
# 72      Adulto          Pontual              Normal                  Apto
# 73  Experiente          Pontual              Normal                Inepto
# 74  Experiente           Tardio                Alto                Inepto
# 75      Adulto        Prematuro              Normal                  Apto
# 76  Experiente          Pontual              Normal                  Apto
# 77      Adulto        Prematuro                Alto                  Apto
# 78      Adulto           Tardio               Baixo                  Apto
# 79      Adulto           Tardio              Normal                  Apto
#
# [80 rows x 10 columns]

# %%
df_cesaria.loc[df_cesaria.Cesariana  ==  0,'Cesariana_desc'] = 'Não'
df_cesaria.loc[df_cesaria.Cesariana  ==  1,'Cesariana_desc'] = 'Sim'

# %%
df_cesaria
# Out:
#     idade  nr_parto  tempo_parto  pressao_sangue  prblm_coracao  Cesariana  \
# 0      22         1            0               2              0          0
# 1      26         2            0               1              0          1
# 2      26         2            1               1              0          0
# 3      28         1            0               2              0          0
# 4      22         2            0               1              0          1
# 5      26         1            1               0              0          0
# 6      27         2            0               1              0          0
# 7      32         3            0               1              0          1
# 8      28         2            0               1              0          0
# 9      27         1            1               1              0          1
# 10     36         1            0               1              0          0
# 11     33         1            1               0              0          1
# 12     23         1            1               1              0          0
# 13     20         1            0               1              1          0
# 14     29         1            2               0              1          1
# 15     25         1            2               0              0          0
# 16     25         1            0               1              0          0
# 17     20         1            2               2              0          1
# 18     37         3            0               1              1          1
# 19     24         1            2               0              1          1
# 20     26         1            1               1              0          0
# 21     33         2            0               0              1          1
# 22     25         1            1               2              0          0
# 23     27         1            0               0              1          1
# 24     20         1            0               2              1          1
# 25     18         1            0               1              0          0
# 26     18         1            1               2              1          1
# 27     30         1            0               1              0          0
# 28     32         1            0               2              1          1
# 29     26         2            1               1              1          0
# ..    ...       ...          ...             ...            ...        ...
# 50     33         3            2               1              1          0
# 51     21         2            1               0              1          1
# 52     30         3            2               2              0          0
# 53     35         1            1               0              0          0
# 54     29         2            0               1              1          1
# 55     25         2            0               1              0          0
# 56     32         3            1               0              1          1
# 57     21         1            0               0              0          1
# 58     26         1            0               2              0          1
# 59     30         2            1               2              1          1
# 60     22         1            2               2              0          0
# 61     19         1            0               1              0          1
# 62     32         2            0               0              0          1
# 63     32         2            0               1              1          1
# 64     31         1            2               2              1          0
# 65     35         2            0               1              0          1
# 66     28         3            0               1              0          1
# 67     29         2            0               1              1          0
# 68     25         1            0               0              0          1
# 69     27         2            2               0              0          0
# 70     17         1            0               0              0          1
# 71     29         1            2               0              1          1
# 72     28         2            0               1              0          0
# 73     32         3            0               1              1          0
# 74     38         3            2               2              1          1
# 75     27         2            1               1              0          0
# 76     33         4            0               1              0          1
# 77     29         2            1               2              0          1
# 78     25         1            2               0              0          1
# 79     24         2            2               1              0          0
#
#    Faixa_idade tempo_parto_desc pressao_sangue_desc problema_coracao_desc  \
# 0       Adulto          Pontual                Alto                  Apto
# 1       Adulto          Pontual              Normal                  Apto
# 2       Adulto        Prematuro              Normal                  Apto
# 3       Adulto          Pontual                Alto                  Apto
# 4       Adulto          Pontual              Normal                  Apto
# 5       Adulto        Prematuro               Baixo                  Apto
# 6       Adulto          Pontual              Normal                  Apto
# 7   Experiente          Pontual              Normal                  Apto
# 8       Adulto          Pontual              Normal                  Apto
# 9       Adulto        Prematuro              Normal                  Apto
# 10  Experiente          Pontual              Normal                  Apto
# 11  Experiente        Prematuro               Baixo                  Apto
# 12      Adulto        Prematuro              Normal                  Apto
# 13       Jovem          Pontual              Normal                Inepto
# 14      Adulto           Tardio               Baixo                Inepto
# 15      Adulto           Tardio               Baixo                  Apto
# 16      Adulto          Pontual              Normal                  Apto
# 17       Jovem           Tardio                Alto                  Apto
# 18  Experiente          Pontual              Normal                Inepto
# 19      Adulto           Tardio               Baixo                Inepto
# 20      Adulto        Prematuro              Normal                  Apto
# 21  Experiente          Pontual               Baixo                Inepto
# 22      Adulto        Prematuro                Alto                  Apto
# 23      Adulto          Pontual               Baixo                Inepto
# 24       Jovem          Pontual                Alto                Inepto
# 25       Jovem          Pontual              Normal                  Apto
# 26       Jovem        Prematuro                Alto                Inepto
# 27      Adulto          Pontual              Normal                  Apto
# 28  Experiente          Pontual                Alto                Inepto
# 29      Adulto        Prematuro              Normal                Inepto
# ..         ...              ...                 ...                   ...
# 50  Experiente           Tardio              Normal                Inepto
# 51       Jovem        Prematuro               Baixo                Inepto
# 52      Adulto           Tardio                Alto                  Apto
# 53  Experiente        Prematuro               Baixo                  Apto
# 54      Adulto          Pontual              Normal                Inepto
# 55      Adulto          Pontual              Normal                  Apto
# 56  Experiente        Prematuro               Baixo                Inepto
# 57       Jovem          Pontual               Baixo                  Apto
# 58      Adulto          Pontual                Alto                  Apto
# 59      Adulto        Prematuro                Alto                Inepto
# 60      Adulto           Tardio                Alto                  Apto
# 61       Jovem          Pontual              Normal                  Apto
# 62  Experiente          Pontual               Baixo                  Apto
# 63  Experiente          Pontual              Normal                Inepto
# 64  Experiente           Tardio                Alto                Inepto
# 65  Experiente          Pontual              Normal                  Apto
# 66      Adulto          Pontual              Normal                  Apto
# 67      Adulto          Pontual              Normal                Inepto
# 68      Adulto          Pontual               Baixo                  Apto
# 69      Adulto           Tardio               Baixo                  Apto
# 70       Jovem          Pontual               Baixo                  Apto
# 71      Adulto           Tardio               Baixo                Inepto
# 72      Adulto          Pontual              Normal                  Apto
# 73  Experiente          Pontual              Normal                Inepto
# 74  Experiente           Tardio                Alto                Inepto
# 75      Adulto        Prematuro              Normal                  Apto
# 76  Experiente          Pontual              Normal                  Apto
# 77      Adulto        Prematuro                Alto                  Apto
# 78      Adulto           Tardio               Baixo                  Apto
# 79      Adulto           Tardio              Normal                  Apto
#
#    Cesariana_desc
# 0             Não
# 1             Sim
# 2             Não
# 3             Não
# 4             Sim
# 5             Não
# 6             Não
# 7             Sim
# 8             Não
# 9             Sim
# 10            Não
# 11            Sim
# 12            Não
# 13            Não
# 14            Sim
# 15            Não
# 16            Não
# 17            Sim
# 18            Sim
# 19            Sim
# 20            Não
# 21            Sim
# 22            Não
# 23            Sim
# 24            Sim
# 25            Não
# 26            Sim
# 27            Não
# 28            Sim
# 29            Não
# ..            ...
# 50            Não
# 51            Sim
# 52            Não
# 53            Não
# 54            Sim
# 55            Não
# 56            Sim
# 57            Sim
# 58            Sim
# 59            Sim
# 60            Não
# 61            Sim
# 62            Sim
# 63            Sim
# 64            Não
# 65            Sim
# 66            Sim
# 67            Não
# 68            Sim
# 69            Não
# 70            Sim
# 71            Sim
# 72            Não
# 73            Não
# 74            Sim
# 75            Não
# 76            Sim
# 77            Sim
# 78            Sim
# 79            Não
#
# [80 rows x 11 columns]

# %%
import numpy as  np

#preprocessamento
from sklearn import preprocessing

#imagens
from IPython.display import Image as img


#bibliotecas Gráficas
import matplotlib.pyplot as plt
import seaborn as sns


from collections import Counter

#Classificadores / Algoritmos
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve

#Validação Modelo
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


import warnings
warnings.filterwarnings('ignore')

# %%
df_cesaria
# Out:
#     idade  nr_parto  tempo_parto  pressao_sangue  prblm_coracao  Cesariana  \
# 0      22         1            0               2              0          0
# 1      26         2            0               1              0          1
# 2      26         2            1               1              0          0
# 3      28         1            0               2              0          0
# 4      22         2            0               1              0          1
# 5      26         1            1               0              0          0
# 6      27         2            0               1              0          0
# 7      32         3            0               1              0          1
# 8      28         2            0               1              0          0
# 9      27         1            1               1              0          1
# 10     36         1            0               1              0          0
# 11     33         1            1               0              0          1
# 12     23         1            1               1              0          0
# 13     20         1            0               1              1          0
# 14     29         1            2               0              1          1
# 15     25         1            2               0              0          0
# 16     25         1            0               1              0          0
# 17     20         1            2               2              0          1
# 18     37         3            0               1              1          1
# 19     24         1            2               0              1          1
# 20     26         1            1               1              0          0
# 21     33         2            0               0              1          1
# 22     25         1            1               2              0          0
# 23     27         1            0               0              1          1
# 24     20         1            0               2              1          1
# 25     18         1            0               1              0          0
# 26     18         1            1               2              1          1
# 27     30         1            0               1              0          0
# 28     32         1            0               2              1          1
# 29     26         2            1               1              1          0
# ..    ...       ...          ...             ...            ...        ...
# 50     33         3            2               1              1          0
# 51     21         2            1               0              1          1
# 52     30         3            2               2              0          0
# 53     35         1            1               0              0          0
# 54     29         2            0               1              1          1
# 55     25         2            0               1              0          0
# 56     32         3            1               0              1          1
# 57     21         1            0               0              0          1
# 58     26         1            0               2              0          1
# 59     30         2            1               2              1          1
# 60     22         1            2               2              0          0
# 61     19         1            0               1              0          1
# 62     32         2            0               0              0          1
# 63     32         2            0               1              1          1
# 64     31         1            2               2              1          0
# 65     35         2            0               1              0          1
# 66     28         3            0               1              0          1
# 67     29         2            0               1              1          0
# 68     25         1            0               0              0          1
# 69     27         2            2               0              0          0
# 70     17         1            0               0              0          1
# 71     29         1            2               0              1          1
# 72     28         2            0               1              0          0
# 73     32         3            0               1              1          0
# 74     38         3            2               2              1          1
# 75     27         2            1               1              0          0
# 76     33         4            0               1              0          1
# 77     29         2            1               2              0          1
# 78     25         1            2               0              0          1
# 79     24         2            2               1              0          0
#
#    Faixa_idade tempo_parto_desc pressao_sangue_desc problema_coracao_desc  \
# 0       Adulto          Pontual                Alto                  Apto
# 1       Adulto          Pontual              Normal                  Apto
# 2       Adulto        Prematuro              Normal                  Apto
# 3       Adulto          Pontual                Alto                  Apto
# 4       Adulto          Pontual              Normal                  Apto
# 5       Adulto        Prematuro               Baixo                  Apto
# 6       Adulto          Pontual              Normal                  Apto
# 7   Experiente          Pontual              Normal                  Apto
# 8       Adulto          Pontual              Normal                  Apto
# 9       Adulto        Prematuro              Normal                  Apto
# 10  Experiente          Pontual              Normal                  Apto
# 11  Experiente        Prematuro               Baixo                  Apto
# 12      Adulto        Prematuro              Normal                  Apto
# 13       Jovem          Pontual              Normal                Inepto
# 14      Adulto           Tardio               Baixo                Inepto
# 15      Adulto           Tardio               Baixo                  Apto
# 16      Adulto          Pontual              Normal                  Apto
# 17       Jovem           Tardio                Alto                  Apto
# 18  Experiente          Pontual              Normal                Inepto
# 19      Adulto           Tardio               Baixo                Inepto
# 20      Adulto        Prematuro              Normal                  Apto
# 21  Experiente          Pontual               Baixo                Inepto
# 22      Adulto        Prematuro                Alto                  Apto
# 23      Adulto          Pontual               Baixo                Inepto
# 24       Jovem          Pontual                Alto                Inepto
# 25       Jovem          Pontual              Normal                  Apto
# 26       Jovem        Prematuro                Alto                Inepto
# 27      Adulto          Pontual              Normal                  Apto
# 28  Experiente          Pontual                Alto                Inepto
# 29      Adulto        Prematuro              Normal                Inepto
# ..         ...              ...                 ...                   ...
# 50  Experiente           Tardio              Normal                Inepto
# 51       Jovem        Prematuro               Baixo                Inepto
# 52      Adulto           Tardio                Alto                  Apto
# 53  Experiente        Prematuro               Baixo                  Apto
# 54      Adulto          Pontual              Normal                Inepto
# 55      Adulto          Pontual              Normal                  Apto
# 56  Experiente        Prematuro               Baixo                Inepto
# 57       Jovem          Pontual               Baixo                  Apto
# 58      Adulto          Pontual                Alto                  Apto
# 59      Adulto        Prematuro                Alto                Inepto
# 60      Adulto           Tardio                Alto                  Apto
# 61       Jovem          Pontual              Normal                  Apto
# 62  Experiente          Pontual               Baixo                  Apto
# 63  Experiente          Pontual              Normal                Inepto
# 64  Experiente           Tardio                Alto                Inepto
# 65  Experiente          Pontual              Normal                  Apto
# 66      Adulto          Pontual              Normal                  Apto
# 67      Adulto          Pontual              Normal                Inepto
# 68      Adulto          Pontual               Baixo                  Apto
# 69      Adulto           Tardio               Baixo                  Apto
# 70       Jovem          Pontual               Baixo                  Apto
# 71      Adulto           Tardio               Baixo                Inepto
# 72      Adulto          Pontual              Normal                  Apto
# 73  Experiente          Pontual              Normal                Inepto
# 74  Experiente           Tardio                Alto                Inepto
# 75      Adulto        Prematuro              Normal                  Apto
# 76  Experiente          Pontual              Normal                  Apto
# 77      Adulto        Prematuro                Alto                  Apto
# 78      Adulto           Tardio               Baixo                  Apto
# 79      Adulto           Tardio              Normal                  Apto
#
#    Cesariana_desc
# 0             Não
# 1             Sim
# 2             Não
# 3             Não
# 4             Sim
# 5             Não
# 6             Não
# 7             Sim
# 8             Não
# 9             Sim
# 10            Não
# 11            Sim
# 12            Não
# 13            Não
# 14            Sim
# 15            Não
# 16            Não
# 17            Sim
# 18            Sim
# 19            Sim
# 20            Não
# 21            Sim
# 22            Não
# 23            Sim
# 24            Sim
# 25            Não
# 26            Sim
# 27            Não
# 28            Sim
# 29            Não
# ..            ...
# 50            Não
# 51            Sim
# 52            Não
# 53            Não
# 54            Sim
# 55            Não
# 56            Sim
# 57            Sim
# 58            Sim
# 59            Sim
# 60            Não
# 61            Sim
# 62            Sim
# 63            Sim
# 64            Não
# 65            Sim
# 66            Sim
# 67            Não
# 68            Sim
# 69            Não
# 70            Sim
# 71            Sim
# 72            Não
# 73            Não
# 74            Sim
# 75            Não
# 76            Sim
# 77            Sim
# 78            Sim
# 79            Não
#
# [80 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
y = np.array(df_cesaria[["Cesariana_desc"]])
X = np.array(df_cesaria.drop(labels = ["Cesariana_desc",
                              "Cesariana",
                              "pressao_sangue_desc",
                              "tempo_parto_desc",
                              "Faixa_idade",
                                "problema_coracao_desc"
                              ],axis = 1)
            )


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
classifier = RandomForestClassifier(random_state=100,criterion='gini',max_depth=3 )
    
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=100, verbose=0, warm_start=False)

# %%
print(classifier.score(X_train, y_train))
print(classifier.score(X_test, y_test))
# Out:
# 0.7678571428571429
# 0.7083333333333334

# %%
y_pred  = classifier.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 7  5]
#  [ 2 10]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          Não       0.78      0.58      0.67        12
#          Sim       0.67      0.83      0.74        12
#
#    micro avg       0.71      0.71      0.71        24
#    macro avg       0.72      0.71      0.70        24
# weighted avg       0.72      0.71      0.70        24

# %%
y_pred
# Out:
# array(['Sim', 'Não', 'Sim', 'Sim', 'Sim', 'Sim', 'Sim', 'Sim', 'Não',
#        'Não', 'Sim', 'Sim', 'Não', 'Não', 'Sim', 'Não', 'Sim', 'Sim',
#        'Sim', 'Sim', 'Sim', 'Não', 'Não', 'Não'], dtype=object)

# %% [markdown]
# ## Matriz de Confusão ##

# %%
print (pd.crosstab(X_test, y_pred, rownames = ['Real'], colnames = ['                  Predido'], margins=True ))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-29-d6483f460509> in <module>
# ----> 1 print (pd.crosstab(X_test, y_pred, rownames = ['Real'], colnames = ['                  Predido'], margins=True ))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     480
#     481     from pandas import DataFrame
# --> 482     df = DataFrame(data, index=common_idx)
#     483     if values is None:
#     484         df['__dummy__'] = 0
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
# -> 7359     arrays = _homogenize(arrays, index, dtype)
#    7360
#    7361     # from BlockManager perspective
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _homogenize(data, index, dtype)
#    7667                 v = lib.fast_multiget(v, oindex.values, default=np.nan)
#    7668             v = _sanitize_array(v, index, dtype=dtype, copy=False,
# -> 7669                                 raise_cast_failure=False)
#    7670
#    7671         homogenized.append(v)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    4163     elif subarr.ndim > 1:
#    4164         if isinstance(data, np.ndarray):
# -> 4165             raise Exception('Data must be 1-dimensional')
#    4166         else:
#    4167             subarr = com._asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%
X_test
# Out:
# array([[33,  3,  2,  1,  1],
#        [30,  1,  0,  1,  0],
#        [25,  1,  0,  0,  0],
#        [29,  2,  1,  2,  0],
#        [28,  3,  0,  1,  1],
#        [29,  1,  2,  0,  1],
#        [28,  3,  0,  1,  0],
#        [25,  1,  0,  0,  0],
#        [26,  2,  2,  1,  0],
#        [27,  2,  2,  0,  0],
#        [27,  1,  0,  2,  1],
#        [32,  2,  0,  1,  1],
#        [26,  2,  1,  1,  0],
#        [28,  2,  0,  1,  0],
#        [30,  3,  2,  2,  0],
#        [26,  2,  2,  1,  0],
#        [28,  1,  0,  2,  0],
#        [25,  1,  1,  2,  0],
#        [32,  3,  0,  1,  0],
#        [18,  1,  1,  2,  1],
#        [36,  1,  1,  2,  0],
#        [31,  1,  0,  1,  0],
#        [19,  1,  0,  1,  0],
#        [24,  2,  2,  1,  0]])

# %%
from pandas import Series

# %%
s = pd.Series(np.random.randn(len(y_test)),index=y_test)
